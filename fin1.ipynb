# %%
import pandas as pd
import numpy as np
import yfinance as yf
import math

# %%
tickers = pd.read_csv('top_50_indian_stocks.csv')
tickers.head()
# Out:
#          Ticker               Company Name
# 0   RELIANCE.NS        Reliance Industries
# 1        TCS.NS  Tata Consultancy Services
# 2   HDFCBANK.NS                  HDFC Bank
# 3       INFY.NS                    Infosys
# 4  ICICIBANK.NS                 ICICI Bank

# %%
def fetch_market_cap(ticker_list):
    data = yf.download(ticker_list, period = '1d', group_by='ticker', auto_adjust=False)

    stocks_data = []
    for ticker in ticker_list:
        latest_price = data[ticker]['Close'].iloc[-1]
        market_cap = yf.Ticker(ticker).info.get("marketCap", 'N/A')
        stocks_data.append({
            "Ticker" : ticker,
            "Market Cap" : market_cap,
            "Latest Price" : latest_price,
        })

    stocks_df = pd.DataFrame(stocks_data)

    return stocks_df



tickers_list = tickers["Ticker"].values.tolist()
df = fetch_market_cap(tickers_list)
df.head()
# Out:
# [*********************100%***********************]  50 of 50 completed
#          Ticker      Market Cap  Latest Price
# 0   RELIANCE.NS  19643735474176   1451.599976
# 1        TCS.NS  11082925080576   3063.199951
# 2   HDFCBANK.NS  15283005685760    994.750000
# 3       INFY.NS   6323255640064   1525.400024
# 4  ICICIBANK.NS   9843569065984   1377.699951

# %%
df
# Out:
#            Ticker      Market Cap  Latest Price
# 0     RELIANCE.NS  19643735474176   1451.599976
# 1          TCS.NS  11082925080576   3063.199951
# 2     HDFCBANK.NS  15283005685760    994.750000
# 3         INFY.NS   6323255640064   1525.400024
# 4    ICICIBANK.NS   9843569065984   1377.699951
# 5   HINDUNILVR.NS   5914860453888   2516.399902
# 6         SBIN.NS   8349093462016    904.500000
# 7   BAJFINANCE.NS   6772943224832   1089.750000
# 8   BHARTIARTL.NS  12168924758016   2029.300049
# 9          ITC.NS   5221602295808    416.799988
# 10   KOTAKBANK.NS   4349051797504   2187.000000
# 11    ADANIENT.NS   2890299342848   2504.199951
# 12          LT.NS   5371408154624   3904.899902
# 13     HCLTECH.NS   4122656899072   1523.800049
# 14  ASIANPAINT.NS   2399369166848   2501.600098
# 15    AXISBANK.NS   3854089060352   1241.900024
# 16   SUNPHARMA.NS   4076470009856   1699.000000
# 17       WIPRO.NS   2544578854912    242.979996
# 18  ULTRACEMCO.NS   3504949952512  11918.000000
# 19    HDFCLIFE.NS   1584973348864    734.950012
# 20        ONGC.NS   3207468154880    254.960007
# 21        NTPC.NS   3292987916288    339.600006
# 22   POWERGRID.NS   2683689238528    288.500000
# 23  TATAMOTORS.NS   1494290006016    403.299988
# 24  INDUSINDBK.NS    588241305600    755.049988
# 25  ADANIGREEN.NS   1698403319808   1031.099976
# 26       TITAN.NS   3295284297728   3714.899902
# 27    DIVISLAB.NS   1750234300416   6593.000000
# 28       TECHM.NS   1287076708352   1453.699951
# 29      MARUTI.NS   5116587409408  16274.000000
# 30   COALINDIA.NS   2428423110656    394.049988
# 31        BPCL.NS   1433659244544    330.450012
# 32    JSWSTEEL.NS   2787923460096   1141.400024
# 33     DRREDDY.NS   1068949700608   1283.599976
# 34  BAJAJFINSV.NS   3447334633472   2159.500000
# 35  ADANIPORTS.NS   3086838661120   1429.000000
# 36       CIPLA.NS   1279823970304   1584.400024
# 37   BRITANNIA.NS   1457975721984   6053.000000
# 38     HAVELLS.NS    937215262720   1494.900024
# 39    SHREECEM.NS   1035697848320  28705.000000
# 40      GRASIM.NS   1927972913152   2841.300049
# 41   TATASTEEL.NS   2175589154816    174.440002
# 42  HEROMOTOCO.NS   1108475904000   5540.500000
# 43         M&M.NS   4350168006656   3625.000000
# 44   EICHERMOT.NS   1876061454336   6840.000000
# 45         IOC.NS   2123410571264    150.369995
# 46     SBICARD.NS    885319794688    928.950012
# 47  PIDILITIND.NS   1533796810752   1507.099976
# 48       DMART.NS   2742416834560   4213.899902
# 49     HDFCAMC.NS   1186329788416   5543.500000

# %%
df = df.sort_values(by = "Market Cap", ascending = False)
df
# Out:
#            Ticker      Market Cap  Latest Price
# 0     RELIANCE.NS  19643735474176   1451.599976
# 2     HDFCBANK.NS  15283005685760    994.750000
# 8   BHARTIARTL.NS  12168924758016   2029.300049
# 1          TCS.NS  11082925080576   3063.199951
# 4    ICICIBANK.NS   9843569065984   1377.699951
# 6         SBIN.NS   8349093462016    904.500000
# 7   BAJFINANCE.NS   6772943224832   1089.750000
# 3         INFY.NS   6323255640064   1525.400024
# 5   HINDUNILVR.NS   5914860453888   2516.399902
# 12          LT.NS   5371408154624   3904.899902
# 9          ITC.NS   5221602295808    416.799988
# 29      MARUTI.NS   5116587409408  16274.000000
# 43         M&M.NS   4350168006656   3625.000000
# 10   KOTAKBANK.NS   4349051797504   2187.000000
# 13     HCLTECH.NS   4122656899072   1523.800049
# 16   SUNPHARMA.NS   4076470009856   1699.000000
# 15    AXISBANK.NS   3854089060352   1241.900024
# 18  ULTRACEMCO.NS   3504949952512  11918.000000
# 34  BAJAJFINSV.NS   3447334633472   2159.500000
# 26       TITAN.NS   3295284297728   3714.899902
# 21        NTPC.NS   3292987916288    339.600006
# 20        ONGC.NS   3207468154880    254.960007
# 35  ADANIPORTS.NS   3086838661120   1429.000000
# 11    ADANIENT.NS   2890299342848   2504.199951
# 32    JSWSTEEL.NS   2787923460096   1141.400024
# 48       DMART.NS   2742416834560   4213.899902
# 22   POWERGRID.NS   2683689238528    288.500000
# 17       WIPRO.NS   2544578854912    242.979996
# 30   COALINDIA.NS   2428423110656    394.049988
# 14  ASIANPAINT.NS   2399369166848   2501.600098
# 41   TATASTEEL.NS   2175589154816    174.440002
# 45         IOC.NS   2123410571264    150.369995
# 40      GRASIM.NS   1927972913152   2841.300049
# 44   EICHERMOT.NS   1876061454336   6840.000000
# 27    DIVISLAB.NS   1750234300416   6593.000000
# 25  ADANIGREEN.NS   1698403319808   1031.099976
# 19    HDFCLIFE.NS   1584973348864    734.950012
# 47  PIDILITIND.NS   1533796810752   1507.099976
# 23  TATAMOTORS.NS   1494290006016    403.299988
# 37   BRITANNIA.NS   1457975721984   6053.000000
# 31        BPCL.NS   1433659244544    330.450012
# 28       TECHM.NS   1287076708352   1453.699951
# 36       CIPLA.NS   1279823970304   1584.400024
# 49     HDFCAMC.NS   1186329788416   5543.500000
# 42  HEROMOTOCO.NS   1108475904000   5540.500000
# 33     DRREDDY.NS   1068949700608   1283.599976
# 39    SHREECEM.NS   1035697848320  28705.000000
# 38     HAVELLS.NS    937215262720   1494.900024
# 46     SBICARD.NS    885319794688    928.950012
# 24  INDUSINDBK.NS    588241305600    755.049988

# %%
df = df.head(10)
df.reset_index(inplace=True, drop = True)
df
# Out:
#           Ticker      Market Cap  Latest Price
# 0    RELIANCE.NS  19643735474176   1451.599976
# 1    HDFCBANK.NS  15283005685760    994.750000
# 2  BHARTIARTL.NS  12168924758016   2029.300049
# 3         TCS.NS  11082925080576   3063.199951
# 4   ICICIBANK.NS   9843569065984   1377.699951
# 5        SBIN.NS   8349093462016    904.500000
# 6  BAJFINANCE.NS   6772943224832   1089.750000
# 7        INFY.NS   6323255640064   1525.400024
# 8  HINDUNILVR.NS   5914860453888   2516.399902
# 9          LT.NS   5371408154624   3904.899902

# %%
portfolio_size = int(input("Enter the amount you want to invest: "))
position_size =  portfolio_size / len(df.index)
position_size
# Out:
# Enter the amount you want to invest: 10000
# 1000.0

# %%
df['Number of Shares to buy'] = df['Latest Price'].apply(lambda price: math.floor(
    position_size / price
))

df
# Out:
# /tmp/ipython-input-3798226014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Number of Shares to buy'] = df['Latest Price'].apply(lambda price: math.floor(
#           Ticker      Market Cap  Latest Price  Number of Shares to buy
# 0    RELIANCE.NS  19643735474176   1451.599976                        0
# 1    HDFCBANK.NS  15283005685760    994.750000                        1
# 2  BHARTIARTL.NS  12168924758016   2029.300049                        0
# 3         TCS.NS  11082925080576   3063.199951                        0
# 4   ICICIBANK.NS   9843569065984   1377.699951                        0
# 5        SBIN.NS   8349093462016    904.500000                        1
# 6  BAJFINANCE.NS   6772943224832   1089.750000                        0
# 7        INFY.NS   6323255640064   1525.400024                        0
# 8  HINDUNILVR.NS   5914860453888   2516.399902                        0
# 9          LT.NS   5371408154624   3904.899902                        0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Market Cap'].plot(kind='hist', bins=20, title='Market Cap')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Latest Price'].plot(kind='hist', bins=20, title='Latest Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Number of Shares to buy'].plot(kind='hist', bins=20, title='Number of Shares to buy')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Market Cap', y='Latest Price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Latest Price', y='Number of Shares to buy', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Market Cap'].plot(kind='line', figsize=(8, 4), title='Market Cap')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Latest Price'].plot(kind='line', figsize=(8, 4), title='Latest Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Number of Shares to buy'].plot(kind='line', figsize=(8, 4), title='Number of Shares to buy')
# plt.gca().spines[['top', 'right']].set_visible(False)
